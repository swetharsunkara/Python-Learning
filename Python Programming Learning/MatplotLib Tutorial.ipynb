# %% [markdown]
# ### MatplotLib Tutorial
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
# – Generally easy to get started for simple plots
# – Support for custom labels and texts
# – Great control of every element in a figure
# – High-quality output in many formats
# – Very customizable in general

# %%
import matplotlib.pyplot as plt

# %matplotlib inline  

# this % line is used to disply the output i.e, graph if this is not wrriten then each time we should write plt.show()

# %%
import numpy as np

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('X axis') #providing x axis label
plt.ylabel('Y axis') #providing y axis label
plt.title('Graph in 2D') #graph label
plt.savefig('Test.png') #tosave the image in local system

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'r*--')
# another way to write above line --> plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %% [markdown]
# ## Creating Subplots

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %% [markdown]
# # Subplot()

# %%
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %% [markdown]
# # Bar Plot

# %%
x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %% [markdown]
# # Histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %% [markdown]
# # Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);  

#patch_artist=false then graph will be displyed in white with orange line

# %%
data
# Out:
# [array([-1.17887824e+00,  3.42654323e+00, -9.19395659e-01,  4.03564206e-01,
#          2.56413649e-03,  6.69816299e-01, -6.04126679e-01, -1.67794200e-01,
#          5.07393382e-01, -1.56650731e+00,  6.90752229e-02,  4.44316706e-01,
#          1.45133606e+00,  1.26213706e+00, -4.30050281e-01,  1.35300463e+00,
#          2.44511439e-01, -7.83355887e-01,  1.57948879e+00,  2.18941251e+00,
#          5.46012820e-01,  4.39220197e-02,  8.51925140e-01, -2.81677279e-01,
#         -5.61702671e-01, -1.31529146e+00,  6.28280856e-01, -2.11314983e+00,
#         -1.41137754e-01,  5.44169190e-01,  4.92202373e-02,  1.05135686e+00,
#         -2.16100595e-01,  1.77578128e+00,  5.17606963e-01,  9.55679590e-01,
#          6.31411373e-01,  5.77421749e-01, -6.01849161e-01,  6.17491836e-01,
#         -1.65283235e-02,  2.97825948e-01, -1.81398700e+00,  7.46126452e-01,
#          7.29918789e-01,  7.90599341e-01, -4.58259775e-01, -5.59362180e-01,
# ...

# %% [markdown]
# # Pie Chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice gap given for 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()
